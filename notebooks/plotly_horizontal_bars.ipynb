# %%
import pandas as pd
import numpy as np
import holoviews as hv
from math import pi

import plotly.offline as ply
import plotly.graph_objs as go
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot


init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
data = pd.read_csv('/Users/michael.chestnut/Documents/DOI/data/cleaned_data.csv')

# %%
df = data.drop(columns='Unnamed: 0')
df.head(5)
# Out:
#              UII                 bureau_name    portfolio_part  \
# 0  010-000002256  Department of the Interior                IT
# 1  010-000002378  Department of the Interior    Admin Services
# 2  010-000001448  Department of the Interior  Mission Delivery
# 3  010-000000310  Department of the Interior    Admin Services
# 4  010-000002321  Department of the Interior    Admin Services
#
#                                     investment_title  \
# 0    IBC - Infrastructure - IT Security & Compliance
# 1                            DOI - FOIA Portal (DOJ)
# 2  OS - Receipts Expenditures and Allocation Mode...
# 3  DOI - Enterprise Facilities Maintenance & Mana...
# 4     DOI - Compliance Support ESF-11/ESF-11 Website
#
#                             fea_service_area      FY18      FY19      FY20  \
# 0  315 - Threat and Vulnerability Management  0.000000  0.000000  0.000000
# 1               319 - Regulatory Compliance   0.000000  0.030000  0.030000
# 2                   101 - Budget Formulation  0.095000  0.103000  0.101000
# 3            129 - Reporting and Information  5.175915  5.175962  5.259022
# 4   008 - Disaster Preparedness and Planning  0.090902  0.106702  0.090902
#
#          date
# 0  2019-04-03
# 1  2019-04-03
# 2  2019-04-03
# 3  2019-04-03
# 4  2019-04-03

# %%
df['trimmed_investment_title'] = df['investment_title'].str.split('-',1).str[1]
df.head(10)
# Out:
#              UII                 bureau_name    portfolio_part  \
# 0  010-000002256  Department of the Interior                IT
# 1  010-000002378  Department of the Interior    Admin Services
# 2  010-000001448  Department of the Interior  Mission Delivery
# 3  010-000000310  Department of the Interior    Admin Services
# 4  010-000002321  Department of the Interior    Admin Services
# 5  010-000000368  Department of the Interior  Mission Delivery
# 6  010-000002434  Department of the Interior    Admin Services
# 7  010-000000657  Department of the Interior    Admin Services
# 8  010-000000330  Department of the Interior                IT
# 9  010-000000372  Department of the Interior  Mission Delivery
#
#                                     investment_title  \
# 0    IBC - Infrastructure - IT Security & Compliance
# 1                            DOI - FOIA Portal (DOJ)
# 2  OS - Receipts Expenditures and Allocation Mode...
# 3  DOI - Enterprise Facilities Maintenance & Mana...
# 4     DOI - Compliance Support ESF-11/ESF-11 Website
# 5  DOI - National Fire Plan Operations and Report...
# 6  IBC - Business Enterprise Acquisition Reportin...
# 7  OS - Electronic Library of Interior Policies (...
# 8            DOI - Infrastructure - End User Support
# 9  DOI - Wildland Fire Decision Support System (W...
#
#                             fea_service_area      FY18      FY19      FY20  \
# 0  315 - Threat and Vulnerability Management  0.000000  0.000000  0.000000
# 1               319 - Regulatory Compliance   0.000000  0.030000  0.030000
# 2                   101 - Budget Formulation  0.095000  0.103000  0.101000
# 3            129 - Reporting and Information  5.175915  5.175962  5.259022
# 4   008 - Disaster Preparedness and Planning  0.090902  0.106702  0.090902
# 5                   318 - Business Analytics  0.285000  1.215000  1.317000
# 6                   318 - Business Analytics  2.103085  2.276024  2.267350
# 7     661 - Document Management and workflow  0.165800  0.165800  0.165800
# 8                  340 - Collaboration Tools  0.000000  0.000000  0.000000
# 9   008 - Disaster Preparedness and Planning  1.019000  1.019000  0.936000
#
#          date                           trimmed_investment_title
# 0  2019-04-03          Infrastructure - IT Security & Compliance
# 1  2019-04-03                                  FOIA Portal (DOJ)
# 2  2019-04-03   Receipts Expenditures and Allocation Model (R...
# 3  2019-04-03   Enterprise Facilities Maintenance & Managemen...
# 4  2019-04-03           Compliance Support ESF-11/ESF-11 Website
# 5  2019-04-03   National Fire Plan Operations and Reporting S...
# 6  2019-04-03   Business Enterprise Acquisition Reporting (BEAR)
# 7  2019-04-03    Electronic Library of Interior Policies (ELIPS)
# 8  2019-04-03                  Infrastructure - End User Support
# 9  2019-04-03      Wildland Fire Decision Support System (WFDSS)

# %%
def assign_colors(portfolio):
    if portfolio == 'IT':
        return '#8dd3c7'
    elif portfolio == 'Mission Delivery':
        return '#ffffb3'
    else:
        return '#bebada'

# %%
def update_bars(bureau='Department of the Interior',fy='FY18'):
    filtered_df = df[['bureau_name','portfolio_part','trimmed_investment_title',fy]]
    filtered_df = filtered_df[filtered_df['bureau_name']==bureau]
    
    #Sort and return top 10 based on FY values
    top10 = filtered_df.nlargest(10,fy)
    top10['color'] = top10['portfolio_part'].apply(assign_colors)
    
    data=[]
    for i in range(0, len(pd.unique(top10['portfolio_part']))):
        data.append(go.Bar(
            x= top10[fy][top10['portfolio_part'] == pd.unique(top10['portfolio_part'])[i]],
            y= top10['trimmed_investment_title'][top10['portfolio_part'] == pd.unique(top10['portfolio_part'])[i]],
            name= pd.unique(top10['portfolio_part'])[i],
            orientation= 'h',
            marker=dict(
                color = top10['color'][top10['portfolio_part'] == pd.unique(top10['portfolio_part'])[i]]
            )   
        ))
            
    layout = go.Layout(
        margin = dict(l = 400, r = 50, b = 50, t = 50, pad = 4),
        xaxis=dict(
            title=str(fy) +' Spending (In Millions)'),
        showlegend=True
    )
    
    fig = go.Figure(data=data,layout=layout)
#     fig = dict(data=[data],layout=layout)
    
    ply.iplot(fig, filename='horizontal-bar')

# %%
update_bars()
# Out:
# <div>
#
#
#             <div id="6fd25703-e82f-4ff9-98cb-af2f62c962a6" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("6fd25703-e82f-4ff9-98cb-af2f62c962a6")) {
#                     Plotly.newPlot(
#                         '6fd25703-e82f-4ff9-98cb-af2f62c962a6',
#                         [{"marker": {"color": ["#8dd3c7", "#8dd3c7", "#8dd3c7", "#8dd3c7", "#8dd3c7", "#8dd3c7"]}, "name": "IT", "orientation": "h", "type": "bar", "uid": "c1975725-d8b6-49c2-adcc-e8ac91a9c1db", "x": [188.165226, 111.677769, 43.980184, 32.446904, 25.417073, 6.4566], "y": [" Infrastructure - Network (WAN)", " Infrastructure - IT Management", " Infrastructure - IT Security & Compliance", " Infrastructure - Data Center & Cloud", " Infrastructure - End User", " Infrastructure - Local Area Network"]}, {"marker": {"color": ["#bebada", "#bebada", "#bebada"]}, "name": "Admin Services", "orientation": "h", "type": "bar", "uid": "646f4654-0e27-45d6-bd90-8d7759908985", "x": [57.93892, 15.220567, 5.175915], "y": [" Financial and Business Management System (FBMS)", " IBC Shared Service Center (HRLOB)", " Enterprise Facilities Maintenance & Management System (FMMS)"]}, {"marker": {"color": ["#ffffb3"]}, "name": "Mission Delivery", "orientation": "h", "type": "bar", "uid": "1e03525e-56ff-46e9-bf8e-63b6dd17cf26", "x": [4.4675], "y": [" Interior Museum Collection Management System (IMCMS)"]}],
#                         {"margin": {"b": 50, "l": 400, "pad": 4, "r": 50, "t": 50}, "showlegend": true, "xaxis": {"title": {"text": "FY18 Spending (In Millions)"}}},
#                         {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('6fd25703-e82f-4ff9-98cb-af2f62c962a6');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>

# %%
filtered_df = df[['bureau_name','portfolio_part','trimmed_investment_title','FY18']]
filtered_df = filtered_df[filtered_df['bureau_name']=='Department of the Interior']

#Sort and return top 10 based on FY values
top10 = filtered_df.nlargest(10,'FY18')
top10['color'] = top10['portfolio_part'].apply(assign_colors)

top10
# Out:
#                    bureau_name    portfolio_part  \
# 49  Department of the Interior                IT
# 58  Department of the Interior                IT
# 44  Department of the Interior    Admin Services
# 32  Department of the Interior                IT
# 33  Department of the Interior                IT
# 16  Department of the Interior                IT
# 29  Department of the Interior    Admin Services
# 31  Department of the Interior                IT
# 3   Department of the Interior    Admin Services
# 19  Department of the Interior  Mission Delivery
#
#                              trimmed_investment_title        FY18    color
# 49                     Infrastructure - Network (WAN)  188.165226  #8dd3c7
# 58                     Infrastructure - IT Management  111.677769  #8dd3c7
# 44    Financial and Business Management System (FBMS)   57.938920  #bebada
# 32          Infrastructure - IT Security & Compliance   43.980184  #8dd3c7
# 33               Infrastructure - Data Center & Cloud   32.446904  #8dd3c7
# 16                          Infrastructure - End User   25.417073  #8dd3c7
# 29                  IBC Shared Service Center (HRLOB)   15.220567  #bebada
# 31                Infrastructure - Local Area Network    6.456600  #8dd3c7
# 3    Enterprise Facilities Maintenance & Managemen...    5.175915  #bebada
# 19   Interior Museum Collection Management System ...    4.467500  #ffffb3
